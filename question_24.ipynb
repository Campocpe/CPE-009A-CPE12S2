# %% [markdown]
# <a href="https://colab.research.google.com/github/Campocpe/CPE-009A-CPE12S2/blob/main/question_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question number 24

a = "({[]})"
b = "([))"
c = ""
