# %% [markdown]
# <a href="https://colab.research.google.com/github/Campocpe/CPE-009A-CPE12S2/blob/main/CPE009_S1_Seatwork_2_1_CAMPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    inputScore = float(input("Score: "))
    inputTotal = float(input("Total: "))

    if inputScore > inputTotal:
      print("\nInvalid Scores.\n")
      inputScore, inputTotal = 0,0
      break
    else:
      rawScore.append(inputScore)
      totalScore.append(inputTotal)

  grade = sum(rawScore) / sum(totalScore)
  grade = grade * 100
  return grade

# %%
# Create a function for the class standing per term
def termCS():
  print("Hands-on Activities: ")
  numHOA = int(input("  How many hands-on activities? "))
  termHOA = termCrit(numHOA)

  print("Quizzes:")
  numQuiz = int(input("  How many quizzes? "))
  termQuiz = termCrit(numQuiz)

  print("Assignment: ")
  numAss = int(input("  How many assignments? "))
  termAss = termCrit(numAss)

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))


  examGrade = (examRaw / examTotal * 100) if examTotal > 0 else 0

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  print(f"Term Result: {grade:.2f}%")
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")
  prelimGrade = termGrade()

  print("Midterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("Final Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  return finalFG

# %%
def convertGrade(finalGrade):
  if finalGrade >= 97.0: return 1.0
  elif finalGrade >= 94.0: return 1.25
  elif finalGrade >= 91.0: return 1.5
  elif finalGrade >= 88.0: return 1.75
  elif finalGrade >= 85.0: return 2.0
  elif finalGrade >= 82.0: return 2.25
  elif finalGrade >= 79.0: return 2.5
  elif finalGrade >= 76.0: return 2.75
  elif finalGrade >= 75.0: return 3.0
  else: return 5.0

# %%
#CHANGES
#1. if a user inputs a 0 on the amount of activities then it would automatically end the program
#2 I changed aw.append(inputScore) % total.append(inputTotal) to change to "inputScore, inputTotal = 0,0 break" so that way it the program could still run even if the user inputs a 0, it would just give 0 to the activity the user has inputed and the program would still continue
#3 I added the grading system of TIP in the code so that it can show if the user has passed or failed and just to overall show how well the user has done during their semester





# Driver Code

# Trial 1
print("Student Grading System")
final_result = semesterGrade()
gpa = convertGrade(final_result)

print("\n" + "="*30)
print(f"FINAL PERCENTAGE: {final_result:.2f}%")
print(f"CONVERTED GRADE: {gpa}")
print("="*30)

# Trial 2

# Trial 3
# Out:
# Student Grading System
# Prelim Grade
# Computing for the term grade.

# %% [markdown]
# **What is the difference from the code you created?**
#
# <Answer here>
