# %% [markdown]
# <a href="https://colab.research.google.com/github/Campocpe/CPE-009A-CPE12S2/blob/main/Pyton_built_in_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pyton built in data types

# %% [markdown]
# Lists

# %%
pi = 3.14159
varlist = [1, 2, 'A', 'B', 'Hello', pi]
print(varlist[0])
# Out:
# 1

# %%
print(varlist[4])
# Out:
# Hello

# %%
varlist.append('World!')
print(varlist[6])
# Out:
# World!

# %%
len(varlist)
# Out:
# 7

# %%
print(varlist[5])
# Out:
# 3.14159

# %%
varlist.remove(pi)
print(varlist[5])
# Out:
# World!
