# %% [markdown]
# <a href="https://colab.research.google.com/github/Campocpe/CPE-009A-CPE12S2/blob/main/PYTON_INTRO__CAMPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 10 > 2:
  print ("10 is greater than 2")
# Out:
# 10 is greater than 10

# %% [markdown]
# Python Comments

# %%
#this is a comment
#this is my name(very bad)
print ("CAMP RAM")
# Out:
# CAMP RAM

# %% [markdown]
# Variable Naming Conventions

# %%
size = 10
size_2 = 5
Size = 'very small lol'

print (size)
print (size_2)
print (Size)
# Out:
# 10.0
# 5
# very small lol

# %% [markdown]
# python variable

# %%
x = 1
a,b,c=1,2,3
b = "sally" #sally is a string
print (a,b,c)
print (b)
# Out:
# 1 2 3
# sally

# %% [markdown]
# Casting

# %%
b="polly" #this is a type of string
b=int(4)
print(b)

b=float (4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() function

# %%
x=5
y="john cena"
print(type(x))
print (type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "doublequotes" or 'single' quote

# %%
y = "johnny"
y = 'john doe'

# %% [markdown]
# Case sensitive

# %%
a = 4
A = "wally"
#A will not overwrite a
print (a)
# Out:
# 4

# %% [markdown]
# Multiple variables

# %%
x,y,z = "uno", "dos", "tres"
print(x)
print(y)
print(z)
# Out:
# uno
# dos
# tres

# %% [markdown]
# One value to multiple variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print ("python programming is " + x)
# Out:
# python programming is enjoying

# %% [markdown]
# Other

# %%
x = "Python is "
y = "enjoying"
z = x + y
print (z)
# Out:
# Python is enjoying

# %% [markdown]
# arithmetic operations

# %%
#addition
x = 5
y = 3
print (x + y)

#subtraction
x = 5
y = 3
dif = x - y
print (dif)

#multiplication
x = 5
y = 3
pro = x * y
print (pro)

#division
x = 5
y = 3
quo = x / y
print (quo)

#Modulo
x = 5
y = 3
mod = x % y
print (mod)

#Exponential
x = 5
y = 3
exp = x ** y
print (exp)

#floor division
x = 5
y = 3
fquo = x // y
print (exp)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 125

# %% [markdown]
# assignment operators

# %%
(+)
s = 1
s += 3
print (s)

s = 1
s -= 3
print (s)

s = 1
s *= 3
print (s)

s = 1
s /= 3
print (s)

s = 1
s %= 3
print (s)

s = 1
s //= 3
print (s)

s = 1
s **= 3
print (s)

s = 1
s &= 3
print (s)

s = 1
s |= 3
print (s)

s = 1
s ^= 3
print (s)

s = 1
s >>= 3
print (s)

s = 1
s <<= 3
print (s)
# Out:
# 4
# -2
# 3
# 0.3333333333333333
# 1
# 0
# 1
# 1
# 3
# 2
# 0
# 8

# %% [markdown]
# comparisson operator

# %%
t = 6
u = 7

print (t==u) #Equal
print (t!=u) #Not equal
print (t>u)  #Greater than
print (t<u)  #Less than
print (t>=u) #Greater than or equal to
print (t<=u) #less than or equal to
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Logical operator

# %%
t = 1
u = 2
print (t < 5 and u < 5) #and
print (t < 5 or u < 5) #or
print (t < 5 and not (u < 5)) #not
# Out:
# True
# True
# False

# %% [markdown]
# Identity operators

# %%
t = 1
u = 2

print (t is u )
print (t is not u )
# Out:
# False
# True

# %% [markdown]
# bitwise operators

# %%
v = 2

print(v&1) # AND
print(v|3) # OR
print(v^1) # XOR
print(~v)  # NOT
print(v<<2)# Zero fill left shift
print(v>>1)# Signed right shift
# Out:
# 0
# 3
# 3
# -3
# 8
# 1
