# %% [markdown]
# <a href="https://colab.research.google.com/github/Campocpe/CPE-009A-CPE12S2/blob/main/question_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Instruction: Insert the link of your program(Colab/Github) here.

Write a program that uses nested loops to print this pattern:

*
**
***
****
*****
****
***
**
*

# %%
#Question 23

a = "*"
b = 1
c = 3
x = b + c
if b < 3:
 print(a)
 if b == 1:
  print(a + a)
  if b < 2:
   print(a + a + a)
   if b < 3:
    print(a + a + a + a)
    if b < 4:
     print(a + a + a + a + a)
    elife
# Out:
# *
# **
# ***
# ****
# *****
